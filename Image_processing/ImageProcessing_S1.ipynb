# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import skimage
import numpy as np

# %%
image = skimage.io.imread('/content/drive/MyDrive/circuls.png')

# %%
image.shape
# Out:
# (600, 600, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image,cmap='gray')

# %%
cropped = image[400:530,400:600]
plt.imshow(cropped,cmap='gray')

# %%
cropped_plus_X = image +10
plt.imshow(cropped_plus_X,cmap='gray')

# %%
plt.imshow(cropped,cmap='gray')

# %%
noise_image = np.random.poisson(lam=3,size=cropped.shape)
plt.imshow(noise_image,cmap='gray')

# %%
noise_image2 = np.random.normal(size=cropped.shape)
plt.imshow(noise_image2,cmap='gray')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cropped_noisey = cropped + noise_image2
plt.imshow(cropped_noisey,cmap='gray')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image2 = skimage.io.imread('/content/drive/MyDrive/test.jpg')

# %%
image2.shape
# Out:
# (688, 688, 3)

# %%
plt.imshow(image2,cmap='gray')

# %%
import cv2

# %%
fs = 10
filter = np.ones((fs,fs))/ fs**2
filter
# Out:
# array([[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01]])

# %%
mean_filtered = cv2.filter2D(image2,-1,filter)

# %%
plt.imshow(mean_filtered,cmap='gray')

# %%
image3 = skimage.io.imread('/content/drive/MyDrive/image2.tif')

# %%
image3.shape
# Out:
# (2048, 2048, 3)

# %%
plt.imshow(image3,cmap='gray')

# %%
plt.imshow(image3[:,:,1],cmap='rainbow')

# %%
plt.imshow(image3[:,:,0],cmap='Reds')

# %%
channel1 = image3[:,:,1]
plt.hist(channel1)
# Out:
# (array([[1.409e+03, 2.660e+02, 2.160e+02, ..., 0.000e+00, 0.000e+00,
#          5.000e+00],
#         [1.411e+03, 2.560e+02, 2.280e+02, ..., 1.000e+00, 4.000e+00,
#          0.000e+00],
#         [1.414e+03, 2.440e+02, 2.410e+02, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         ...,
#         [1.810e+03, 1.690e+02, 5.400e+01, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [1.825e+03, 1.670e+02, 4.200e+01, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [1.815e+03, 1.780e+02, 4.300e+01, ..., 1.000e+00, 0.000e+00,
#          0.000e+00]]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 2048 BarContainer objects>)

# %% [markdown]
# ### اگر بخوایم درون سلول داشته باشیم باید به رنگ آبی توجه کنیم چون داخل سلول آبی رنگ هست

# %%
plt.imshow(image3[:,:,2],cmap='gray')

# %%
plt.hist(image3[:,:,2])
# Out:
# (array([[1224.,   50.,   73., ...,   66.,   52.,   84.],
#         [1228.,   49.,   80., ...,   83.,   52.,   79.],
#         [1234.,   55.,   69., ...,   81.,   52.,   83.],
#         ...,
#         [1746.,    5.,   34., ...,   29.,   13.,   10.],
#         [1747.,    7.,   30., ...,   22.,   13.,    5.],
#         [1745.,    9.,   24., ...,   24.,   12.,    2.]]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 2048 BarContainer objects>)

# %%
imgage3_nuclie = image3[:,:,2]
mask = imgage3_nuclie>60
plt.imshow(mask,cmap='gray')

# %%
image3_body = image3[:,:,0]
mask_body = image3_body>40
plt.imshow(mask_body,cmap='gray')

# %%
both_mask = imgage3_nuclie * image3_body
plt.imshow(both_mask,cmap='gray')
